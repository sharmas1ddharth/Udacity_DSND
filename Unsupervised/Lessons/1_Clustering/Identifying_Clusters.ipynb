# %% [markdown]
# ### Identifying Clusters
#
# Before we get too far along, let's take a look at some different sets of data to practice identifying clusters.
#
# Start by running the cell below.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import helper_functions as h
import test_file as t
from IPython import display
0
# %matplotlib inline

# Make the images larger
plt.rcParams['figure.figsize'] = (16, 9)

# %% [markdown]
# `1.` Run the cell below to generate a set of data.  Then enter an integer next to **`question_1_clusters`** that identifies the number of clusters you think appear in the plot.
#
# If you think that there are 2 clusters in the plot, you should enter:
#
# ```
# question_1_clusters = 2
# ```

# %%
h.plot_q1_data()
# Out:
# c:\Users\Siddharth\Downloads\udacity lab\DSND_Term1-master\DSND_Term1-master\lessons\Unsupervised\1_Clustering\helper_functions.py:12: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
question_1_clusters = 4 # Enter the number of clusters you see here as an integer

#Then this will test your number against what we used to generate the data
t.test_question_1(question_1_clusters)
# Out:
# That's right!  There are 4 clusters in this dataset.

# %% [markdown]
# `2.` Run the cell below to generate a set of data.  Then, similar to the first question, enter the number of clusters you think appear in the plot.

# %%
h.plot_q2_data()

# %%
question_2_clusters = 2 # Enter the number of clusters you see here as an integer

#Then this will test your number against what we used to generate the data
t.test_question_2(question_2_clusters)
# Out:
# That's right!  There are 2 clusters in this dataset.

# %% [markdown]
# `3.` Run the cell below to generate a set of data.  Then, similar to the previous questions, enter the number of clusters you think appear in the plot.

# %%
h.plot_q3_data()
# Out:
# c:\Users\Siddharth\Downloads\udacity lab\DSND_Term1-master\DSND_Term1-master\lessons\Unsupervised\1_Clustering\helper_functions.py:28: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
question_3_clusters = 7 # Enter the number of clusters you see here as an integer

#Then this will test your number against what we used to generate the data
t.test_question_3(question_3_clusters)
# Out:
# 7 is a reasonable guess for a the number of clusters here.  In the next question, you will see a different angle of this data.

# %% [markdown]
# `4.` Now one final time, run the cell below, and identify the number of clusters you think are in the plot created.

# %%
h.plot_q4_data()
# Out:
# c:\Users\Siddharth\Downloads\udacity lab\DSND_Term1-master\DSND_Term1-master\lessons\Unsupervised\1_Clustering\helper_functions.py:34: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
question_4_clusters = 7 # Enter the number of clusters you see here as an integer

#Then this will test your number against what we used to generate the data
display.HTML(t.test_question_4(question_4_clusters))
# Out:
# This data is actually the same as the data used in question 3.  Isn't it crazy how looking at data from a different angle can make us believe there are a different number of clusters in the data!  We will look at how to address this in the upcoming parts of this lesson.
# <img src="http://www.reactiongifs.com/wp-content/uploads/2013/03/mind-blown.gif">

# %% [markdown]
# **You can find a solution to this by clicking the orange jupyter image at the top of this notebook.**
